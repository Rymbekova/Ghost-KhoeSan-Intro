# %% [markdown]
# ### After getting tracts.bed files from s* output and diploid.txt files from skov output:

# %%
module load conda
conda activate sstar-analysis
module load bedtools

# %% [markdown]
# #### 1) To filter skov output by threshold 85%,90% and 95%:

# %%
for f in *.txt; do awk '$5 == "Archaic" && $6 >= 0.85 && $7 > 20 { print $1 "\t" $2 "\t" $3 }' "$f" > "${f%.txt}.85.bed"; done

# %%
for f in *.txt; do awk '$5 == "Archaic" && $6 >= 0.90 && $7 > 20 { print $1 "\t" $2 "\t" $3 }' "$f" > "${f%.txt}.90.bed"; done

# %%
for f in *.txt; do awk '$5 == "Archaic" && $6 >= 0.95 && $7 > 20 { print $1 "\t" $2 "\t" $3 }' "$f" > "${f%.txt}.95.bed"; done

# %% [markdown]
# #### To concatenate all skov inferred fragments also by threshold:

# %%
cat KSP062.1.ref50.tgt1.recode.diploid.85.bed KSP062.2.ref50.tgt1.recode.diploid.85.bed KSP062.3.ref50.tgt1.recode.diploid.85.bed KSP062.4.ref50.tgt1.recode.diploid.85.bed KSP062.5.ref50.tgt1.recode.diploid.85.bed KSP062.6.ref50.tgt1.recode.diploid.85.bed KSP062.7.ref50.tgt1.recode.diploid.85.bed KSP062.8.ref50.tgt1.recode.diploid.85.bed KSP062.9.ref50.tgt1.recode.diploid.85.bed KSP062.10.ref50.tgt1.recode.diploid.85.bed KSP062.11.ref50.tgt1.recode.diploid.85.bed KSP062.12.ref50.tgt1.recode.diploid.85.bed KSP062.13.ref50.tgt1.recode.diploid.85.bed KSP062.14.ref50.tgt1.recode.diploid.85.bed KSP062.15.ref50.tgt1.recode.diploid.85.bed KSP062.16.ref50.tgt1.recode.diploid.85.bed KSP062.17.ref50.tgt1.recode.diploid.85.bed KSP062.18.ref50.tgt1.recode.diploid.85.bed KSP062.19.ref50.tgt1.recode.diploid.85.bed KSP062.20.ref50.tgt1.recode.diploid.85.bed KSP062.21.ref50.tgt1.recode.diploid.85.bed KSP062.22.ref50.tgt1.recode.diploid.85.bed > KSP062.all.merged.85.bed

# %%
cat KSP062.1.ref50.tgt1.recode.diploid.90.bed KSP062.2.ref50.tgt1.recode.diploid.90.bed KSP062.3.ref50.tgt1.recode.diploid.90.bed KSP062.4.ref50.tgt1.recode.diploid.90.bed KSP062.5.ref50.tgt1.recode.diploid.90.bed KSP062.6.ref50.tgt1.recode.diploid.90.bed KSP062.7.ref50.tgt1.recode.diploid.90.bed KSP062.8.ref50.tgt1.recode.diploid.90.bed KSP062.9.ref50.tgt1.recode.diploid.90.bed KSP062.10.ref50.tgt1.recode.diploid.90.bed KSP062.11.ref50.tgt1.recode.diploid.90.bed KSP062.12.ref50.tgt1.recode.diploid.90.bed KSP062.13.ref50.tgt1.recode.diploid.90.bed KSP062.14.ref50.tgt1.recode.diploid.90.bed KSP062.15.ref50.tgt1.recode.diploid.90.bed KSP062.16.ref50.tgt1.recode.diploid.90.bed KSP062.17.ref50.tgt1.recode.diploid.90.bed KSP062.18.ref50.tgt1.recode.diploid.90.bed KSP062.19.ref50.tgt1.recode.diploid.90.bed KSP062.20.ref50.tgt1.recode.diploid.90.bed KSP062.21.ref50.tgt1.recode.diploid.90.bed KSP062.22.ref50.tgt1.recode.diploid.90.bed > KSP062.all.merged.90.bed

# %%
cat KSP062.1.ref50.tgt1.recode.diploid.95.bed KSP062.2.ref50.tgt1.recode.diploid.95.bed KSP062.3.ref50.tgt1.recode.diploid.95.bed KSP062.4.ref50.tgt1.recode.diploid.95.bed KSP062.5.ref50.tgt1.recode.diploid.95.bed KSP062.6.ref50.tgt1.recode.diploid.95.bed KSP062.7.ref50.tgt1.recode.diploid.95.bed KSP062.8.ref50.tgt1.recode.diploid.95.bed KSP062.9.ref50.tgt1.recode.diploid.95.bed KSP062.10.ref50.tgt1.recode.diploid.95.bed KSP062.11.ref50.tgt1.recode.diploid.95.bed KSP062.12.ref50.tgt1.recode.diploid.95.bed KSP062.13.ref50.tgt1.recode.diploid.95.bed KSP062.14.ref50.tgt1.recode.diploid.95.bed KSP062.15.ref50.tgt1.recode.diploid.95.bed KSP062.16.ref50.tgt1.recode.diploid.95.bed KSP062.17.ref50.tgt1.recode.diploid.95.bed KSP062.18.ref50.tgt1.recode.diploid.95.bed KSP062.19.ref50.tgt1.recode.diploid.95.bed KSP062.20.ref50.tgt1.recode.diploid.95.bed KSP062.21.ref50.tgt1.recode.diploid.95.bed KSP062.22.ref50.tgt1.recode.diploid.95.bed > KSP062.all.merged.95.bed

# %% [markdown]
# #### 2) To merge s* output:

# %%
for f in *.tracts.bed; do bedtools merge -i "$f" > "${f%.tracts.bed}.merged.tracts.bed"; done

# %% [markdown]
# #### To concatenate all s* inferred tracts of an individual:

# %%
awk '{print $1 "\t" $2 "\t" $3}' *.merged.tracts.bed | sort -k1,1V -k2,2n | cut -f1-3 > KSP062.all.merged.tracts.bed

# %% [markdown]
# #### 3) To get the total length of tracts inferred by each of the methods:

# %% [markdown]
# total_length_tracts.py

# %% [markdown]
# #### 4) To get the total overlap and the overlap between each chromosome between skov diploid.bed files (85/90/95% probability) and s* merged.tracts.bed:

# %% [markdown]
# overlap_85.sh

# %% [markdown]
# overlap_90.sh

# %% [markdown]
# overlap_95.sh

# %% [markdown]
# #### 5) To get the proportion of the overlap, multiply total overlap by 100 and divide by the total length of s* outliers (on average 70%)

# %% [markdown]
# #### 6) To retrieve the overlaped regions between s* outliers and hmmix fragments:

# %% [markdown]
# overlap_regions_90.sh

# %% [markdown]
# #### 7) To calculate the proportion of the overlap between random fragments of the same length as inferred tracts: (on average 10%)

# %% [markdown]
# random_overlap.py

# %% [markdown]
# #### 8) To create random genomic regions of equal length distribution and SNP count for each individual's overlap:

# %% [markdown]
# create_random_regions_snps.py

# %% [markdown]
# #### 9) Sort and concat overlapped regions to get final overlap per individual. Sort and concat random regions to get final random per individual

# %% [markdown]
# #### 10) To calculate pairwise base pairs differences between target individuals and between target and ref within each target individual's final overlap regions:

# %% [markdown]
# target_sum.sh

# %% [markdown]
# #### 11) To calculate pairwise base pairs differences between ref individuals within each target individual's final overlap regions:

# %% [markdown]
# ref_sum.sh

# %% [markdown]
# #### 12) To calculate pairwise base pairs differences between target individuals and between target and ref within each target individual's final random regions:

# %% [markdown]
# random_target_sum.sh

# %% [markdown]
# #### 13) To calculate pairwise base pairs differences between ref individuals within each target individual's final random regions:

# %% [markdown]
# random_ref_sum.sh

# %% [markdown]
# #### 14) To visualize the four resulted csv files from pairwise base pairs differences:

# %% [markdown]
# PBD.ipynb

# %% [markdown]
# #### 15) To visualize the overlap between putative introgressed regions between target individuals and create a heatmap:

# %% [markdown]
# Heatmap.ipynb

# %% [markdown]
# #### 16) To run Principal Component Analysis on all individuals within one target individual's putative introgressed regions:

# %% [markdown]
# PCA_regions.ipynb

# %% [markdown]
# #### 17) To run Principal Component Analysis on all individuals within one target individual's random genomic regions:

# %% [markdown]
# random_PCA_regions.ipynb

# %% [markdown]
# #### 18) To visualize all target individuals' putative introgressed regions distribution along the circular genome:

# %% [markdown]
# circle_intro_distribution.R

# %% [markdown]
# #### 19) To calculate heterozygosity in putative introgressed regions and 100 generated genomic regions of same number of informative SNPs and length distribution per individual (it will call the additional two scripts):

# %% [markdown]
# random_regions_heteroz.py

# %% [markdown]
# heterozygosity_real.py, heterozygosity_random.py

# %% [markdown]
# #### 20) To calculate gene density in putative introgressed regions and 100 generated genomic regions of same number of informative SNPs and length distribution per individual:

# %% [markdown]
# random_regions_gened.py

# %% [markdown]
# ### Mutational tolerance

# %% [markdown]
# #### 21) To calculate dN/ds ratio in putative introgressed regions vs one set of random genomic ranges of same number of informative SNPs and length distribution per individual:

# %% [markdown]
# ind_calc_mis.py, ind_calc_syn.py

# %% [markdown]
# #### 22) To calculate the proportion of high impact sites for GERP scores in putative introgressed regions vs one set of random genomic ranges of same number of informative SNPs and length distribution per individual:

# %% [markdown]
# ind_calc_gerp_high.py, ind_calc_gerp_low.py

# %% [markdown]
# #### 23) To calculate the proportion of high impact sites for SIFT scores in putative introgressed regions vs one set of random genomic ranges of same number of informative SNPs and length distribution per individual:

# %% [markdown]
# ind_calc_sift_tol.py, ind_calc_sift_del.py

# %% [markdown]
# #### 24) To calculate the proportion of high impact sites for PolyPhen-2 scores in putative introgressed regions vs one set of random genomic ranges of same number of informative SNPs and length distribution per individual:

# %% [markdown]
# ind_calc_pp_ben.py, ind_calc_pp_dam.py

# %% [markdown]
# #### 25) To calculate the mean LINSIGHT score within putative introgressed regions vs one set of random genomic ranges of same number of informative SNPs and length distribution per individual:

# %% [markdown]
# calculate_linsight_individual.R
